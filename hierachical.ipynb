# %%
class person:
    def __init__(self,name,age):
        self.name=name
        self.age=age
class student(person):
    def __init__(self,name,age,marks):
        super().__init__(name,age)
        self.marks=marks
    def display(self):
        print("name:",self.name)
        print("age:",self.age)
        print("marks:",self.marks)
class teacher(person):
    def __init__(self,name,age,subject):
        super().__init__(name,age)
        self.subject=subject
    def display(self):
        print("name:",self.name)
        print("age:",self.age)
        print("marks:",self.subject)
s=student("akshitha",21,99)
s.display()
t=teacher("akshitha",21,"english")
t.display()
# Out:
# name: akshitha
# age: 21
# marks: 99
# name: akshitha
# age: 21
# marks: english

# %% [markdown]
# 2. Animal → Dog, Cat
# Question
# Define class Animal with method eat(). Create subclasses Dog and Cat.
# Concept
# • Method inheritance.
# How to Solve
# 1. Create parent class Animal.
# 2. Write method eat().
# 3. Create child classes Dog and Cat.
# 4. Create objects.
# 5. Call eat() using both objects.

# %%
class animal:
    def eat(self):
        print("animal is eating")
class dog(animal):
    def eat(self):
        print("dog is eating")
class cat(animal):
    def eat(self):
        print("cat is eating")
d=dog()
c=cat()
d.eat()
c.eat()
# Out:
# dog is eating
# cat is eating

# %% [markdown]
# 3. Vehicle → Car, Bike
# Question
# Create class Vehicle with method start(). Create subclasses Car and Bike.
# Concept
# • One parent method shared by multiple children.
# How to Solve
# 1. Create Vehicle.
# 2. Add start().
# 3. Inherit it in Car.
# 4. Inherit it in Bike.
# 5. Call start() from both child objects.

# %%
class vehicle:
    def start(self):
        print("vehicle is started")
class car(vehicle):
    def start(self):
        print("car is started")
class bike(vehicle):
    def start(self):
        print("bike is started")    
c=car()
b=bike()
c.start()
b.start()
# Out:
# car is started
# bike is started

# %% [markdown]
# 4. Shape → Circle, Rectangle
# Question
# Define class Shape with method area(). Create subclasses Circle and Rectangle.
# Concept
# • Parent provides common method.
# • Children may later override it.
# How to Solve
# 1. Create Shape.
# 2. Add area().
# 3. Create Circle.
# 4. Create Rectangle.
# 5. Call area().

# %%
class shape:
    def area(Self):
        pass
class circle(shape):
    def __init__(self,radius):
        self.radius=radius
    def area(self):
        print("area of circle:", 3.14 * self.radius * self.radius)
class rectangle(shape):
    def __init__(self,length,width):
        self.length = length
        self.width = width
    def area(self):
        print("area of rectangle:", self.length * self.width)
c=circle(2)
c.area()
r=rectangle(2,3)
r.area()
# Out:
# area of circle: 12.56
# area of rectangle: 6

# %% [markdown]
# 5. Employee → Manager, Developer
# Question
# Create class Employee with attributes emp_id and salary. Create subclasses Manager and
# Developer.
# Concept
# • Attribute inheritance.
# How to Solve
# 1. Create parent constructor.
# 2. Store emp_id and salary.
# 3. Create two child classes.
# 4. Show inherited attributes.

# %%
class employee:
    def __init__(self,emp_id,salary):
        self.emp_id = emp_id
        self.salary = salary
class manager(employee):
    def display(self):
        print("emp_id:",self.emp_id)
        print("salary:",self.salary)
class developer(employee):
    def display(self):
        print("emp_id:",self.emp_id)
        print("salary:",self.salary)
m=manager(1234,20000)
d=developer(12345,80000)
m.display()
d.display()
# Out:
# emp_id: 1234
# salary: 20000
# emp_id: 12345
# salary: 80000

# %% [markdown]
# 6. BankAccount → SavingsAccount, CurrentAccount
# Question
# Define class BankAccount with method deposit().
# Concept
# • Common banking functionality.
# How to Solve
# 1. Create deposit().
# 2. Create two child classes.
# 3. Call deposit() from both.

# %%
class bank_acc:
    def __init__(self,balance):
        self.balance = balance
    def deposit(self,amt):
        self.balance += amt
        print("balance:",self.balance)
class savings_acc(bank_acc):
    def deposit(self,amt):
        self.balance += amt
        print("saving balance:",self.balance)
class current_acc(bank_acc):
    def deposit(self,amt):
        self.balance += amt
        print("current balance:",self.balance)
s=savings_acc(10000)
c=current_acc(20000)
s.deposit(10000)
c.deposit(30000)
# Out:
# saving balance: 20000
# current balance: 50000

# %% [markdown]
# 7. Device → Mobile, Laptop
# Question
# Create class Device with method turn_on().
# Concept
# • Reusing common functionality.
# How to Solve
# 1. Create parent.
# 2. Add turn_on().
#
# 3. Create two children.
# 4. Demonstrate inheritance.

# %%
class device:
    def turn_on(self):
        print("turn on the device")
class mobile(device):
    def turn_on(self):
        print("turn on the mobile")
class laptop(device):
    def turn_on(self):
         print("turn on the laptop")
m=mobile()
l=laptop()
m.turn_on()
l.turn_on()
# Out:
# turn on the mobile
# turn on the laptop

# %% [markdown]
# 8. Sports → Cricket, Football
# Question
# Define class Sports with method play().
# Concept
# • Common method inherited.
# How to Solve
# 1. Parent class.
# 2. Common method.
# 3. Two subclasses.
# 4. Call inherited method.

# %%
class sports:
    def play(self):
        print("playing sports")
class cricket:
    def play(self):
        print("playing cricket")
class football:
    def play(self):
        print("football cricket")
c=cricket()
f=football()
c.play()
f.play()
# Out:
# playing cricket
# football cricket

# %% [markdown]
# 9. Product → Electronics, Clothing
# Question
# Create class Product with attribute price.
# Concept
# • Common data shared by children.
# How to Solve
# 1. Create constructor.
# 2. Store price.
# 3. Create child classes.
# 4. Display price.

# %%
class product:
    def __init__(self,price):
        self.price = price
class electronics(product):
    def __init__(self,price):
        super().__init__(price)
    def details(self):
        print("price :",self.price)
class clothing(product):
    def __init__(self,price):
        super().__init__(price)
    def details(self):
        print("price :",self.price)
e=electronics(3000)
c=clothing(4000)
e.details()
c.details()
# Out:
# price : 3000
# price : 4000

# %% [markdown]
# 10. Book → Fiction, NonFiction
# Question
# Define class Book with attributes title and author.
#
# Concept
# • Constructor inheritance.
# How to Solve
# 1. Parent constructor.
# 2. Two child classes.
# 3. Access inherited attributes.

# %%
class book:
    def __init__(self,title,author):
        self.title = title
        self.author = author
class fiction(book):
    def __init__(self,title,author):
        super().__init__(title,author)
    def display(self):
        print("fiction book title:",self.title)
        print("fiction book author:",self.author)
class nonfiction(book):
    def __init__(self,title,author):
        super().__init__(title,author)
    def display(self):
        print("nonfiction book title:",self.title)
        print("nonfiction book author:",self.author)
f=fiction("Harry Potter","J. K. Rowling")
n=nonfiction("Wings of Fire","Atomic Habits")
f.display()
n.display()
# Out:
# fiction book title: Harry Potter
# fiction book author: J. K. Rowling
# nonfiction book title: Wings of Fire
# nonfiction book author: Atomic Habits

# %% [markdown]
# 11. Account → UserAccount, AdminAccount
# Question
# Define class Account with method show_balance().
# Concept
# • Shared functionality.
# How to Solve
# 1. Create method.
# 2. Inherit into both children.
# 3. Call method.

# %%
class acc:
    def __init__(self,balance):
        self.balance = balance
    def show_balance(self):
        print("showing the balance")
class user_acc(acc):
    def show_balance(self):
        print("user acc balance:",self.balance)
class admin_acc(acc):
    def show_balance(self):
        print("admin acc balance:",self.balance)
u=user_acc(100)
a=admin_acc(200)
u.show_balance()
a.show_balance()
# Out:
# user acc balance: 100
# admin acc balance: 200

# %% [markdown]
# 12. Transport → Bus, Train
# Question
# Define class Transport with method move().
# Concept
# • One behavior for many children.
# How to Solve
# 1. Parent class.
# 2. Add method.
# 3. Create Bus.
# 4. Create Train.
# 5. Demonstrate inheritance.

# %%
class transport:
    def move(self):
        print("moving transport")
class bus(transport):
    def move(self):
        print(" bus is moving")
class train(transport):
    def move(self):
        print(" train is moving")
b=bus()
t=train()
b.move()
t.move()
# Out:
#  bus is moving
#  train is moving

# %% [markdown]
# #Hierarchical Inheritance with Constructors & Methods

# %% [markdown]
# 13. Person Constructor
# Concept
# Using super() to call the parent constructor.
# How to Solve
# 1. Create constructor in parent.
# 2. Create child constructors.
# 3. Use super().__init__().
# 4. Add child-specific attribute.
# 5. Display all data.

# %%
class person:
    def __init__(self,name,age):
        self.name = name
        self.age = age
class student(person):
    def __init__(self,name,age,course):
        super().__init__(name,age)
        self.course = course
    def display(self):
        print("name:",self.name)
        print("age:",self.age)
        print("course:",self.course)
s = student("akshitha",21,"data science")
s.display()
# Out:
# name: akshitha
# age: 21
# course: data science

# %% [markdown]
# 14. Animal Sound Override
# Concept
# Method Overriding.
# How to Solve
# 1. Parent has sound().
# 2. Dog overrides.
# 3. Cat overrides.
# 4. Call method from each object.

# %%
class animal:
    def sound(Self):
        print("animal sound")
class dog(animal):
    def sound(Self):
        print("dog sound")
class cat(animal):
    def sound(Self):
        print("cat sound")
d=dog()
c=cat()
d.sound()
c.sound()
# Out:
# dog sound
# cat sound

# %% [markdown]
# 15. Vehicle Constructor
# Concept
# Constructor inheritance.
# How to Solve
# 1. Parent stores brand.
# 2. Car adds doors.
# 3. Bike adds engine_cc.
# 4. Use super().

# %%
class vehicle:
    def __init__(self,brand):
        self.brand = brand
class car(vehicle):
    def __init__(self,brand,doors):
        super().__init__(brand)
        self.doors = doors
    def display(self):
        print("brand of car:",self.brand)
        print("no of doors of car:",self.doors)
class bike(vehicle):
    def __init__(self,brand,engine):
        super().__init__(brand)
        self.engine = engine
    def display(self):
        print("brand of bike:",self.brand)
        print("engine of bike:",self.engine)
c = car("Toyota",4)
b = bike("yamaha","155cc")
c.display()
b.display()
# Out:
# brand of car: Toyota
# no of doors of car: 4
# brand of bike: yamaha
# engine of bike: 155cc

# %% [markdown]
# 17. Employee Details
# Concept
# Method Extension.
# How to Solve
# 1. Parent has get_details().
# 2. Child calls parent method.
# 3. Add child information.
# 4. Display complete details.

# %%
class employee:
    def __init__(self,name,salary):
        self.name = name
        self.salary = salary
    def get_details(self):
        return self.name
    def get_details(self):
        return self.salary
class manager(employee):
    def __init__(self,name,salary,team_size):
        super().__init__(name,salary)
        self.team_size = team_size
    def get_details(self):
        parent_details = super().get_details()
        print(parent_details)
        print("team size:",self.team_size)
m=manager("aksh",60000,11)
m.get_details()
# Out:
# 60000
# team size: 11

# %% [markdown]
# 18. BankAccount Interest
# Concept
# Different child behavior.
# How to Solve
# 1. Parent constructor.
# 2. Savings has one interest.
# 3. Current has another.
# 4. Calculate separately.

# %%
class b_a:
    def __init__(self,balance):
        self.balance = balance
class svings_acc(b_a):
    def cal_interest(self):
        interest = self.balance * 0.50 
        print("savings acc interest:",self.balance)
class current_acc(b_a):
    def cal_interest(self):
        interest = self.balance * 0.20 
        print("current acc interest:",self.balance)
s = svings_acc(10000)
c = current_acc(20000)
s.cal_interest()
c.cal_interest()
# Out:
# savings acc interest: 10000
# current acc interest: 20000

# %% [markdown]
# 19. Device Info
# Concept
# Method overriding.
# How to Solve
# 1. Parent method info().
# 2. Phone overrides.
# 3. Tablet overrides.

# %%
class device_info:
    def info(self):
        print("this phone is device")
class phone(device_info):
    def info(self):
        print ("this is phone")
class tablet(device_info):
    def info(self):
        print("this is tablet")
p=phone()
t=tablet()
p.info()
t.info()
# Out:
# this is phone
# this is tablet

# %% [markdown]
# 20. Game Start
# Concept
# Inheritance + Additional Methods.
# How to Solve
# 1. Parent method start().
# 2. Chess inherits.
# 3. Chess adds checkmate().
# 4. Ludo adds roll_dice().

# %%
class game:
    def start(self):
        print("game is started")
class chess(game):
    def checkmate(self):
        print("checkmate")
class ludo(game):
    def roll_dice(self):
        print("roll_dice")
c=chess("chess")
l=ludo("ludo")
c.start()
c.checkmate()
l.start()
l.roll_dice()
# Out:
# game is started
# checkmate
# game is started
# roll_dice

# %% [markdown]
# 21. Private Attribute
# Concept
# Encapsulation + Inheritance.
# How to Solve
# 1. Parent has private attribute.
# 2. Create getter.
# 3. Child uses getter.
# 4. Display value.

# %%
class Person:
    def __init__(self, name):
        self.__name = name       
    def get_name(self):          
        return self.__name
class Student(Person):
    def display(self):
        print("Name:", self.get_name())
s = Student("Akshitha")
s.display()
# Out:
# Name: Akshitha

# %% [markdown]
# 22. Method Overriding
# Concept
# Both children implement their own version.
# How to Solve
# 1. Parent method.
# 2. Child 1 overrides.
# 3. Child 2 overrides.
# 4. Call method using different objects.

# %%
class Animal:
    def sound(self):
        print("Animal makes a sound")
class Dog(Animal):
    def sound(self):
        print("Dog barks")
class Cat(Animal):
    def sound(self):
        print("Cat meows")
d = Dog()
c = Cat()
d.sound()
c.sound()
# Out:
# Dog barks
# Cat meows

# %% [markdown]
# #Problem / Practical Questions

# %% [markdown]
# 23. School Management
# Concept
# Real-world hierarchical inheritance.
# How to Solve
# 1. Parent → Person
# 2. Common attributes (name, age)
# 3. Student → marks
# 4. Teacher → subject
# 5. Staff → department
# 6. Display information.

# %%
class person:
    def __init__(self,name,age):
        self.name = name
        self.age = age
class student(person):
    def __init__(self,name,age,marks):
        super().__init__(name,age)
        self.marks = marks
    def display(self):
        print("name:",self.name)
        print("age:",self.age)
        print("marks:",self.marks)
class teacher(person):
    def __init__(self,name,age,sub):
        super().__init__(name,age)
        self.sub = sub
    def display(self):
        print("name:",self.name)
        print("age:",self.age)
        print("sub:",self.sub)
class staff(person):
    def __init__(self,name,age,dept):
        super().__init__(name,age)
        self.dept = dept
    def display(self):
        print("name:",self.name)
        print("age:",self.age)
        print("dept:",self.dept)
s=student("aks",21,99)
t=teacher("aks",21,"english")
st=staff("aks",21,"software developer")
s.display()
t.display()
st.display()
# Out:
# name: aks
# age: 21
# marks: 99
# name: aks
# age: 21
# sub: english
# name: aks
# age: 21
# dept: software developer

# %% [markdown]
# 24. Bank System
# Concept
# Three children inherit one parent.
# How to Solve
# 1. Parent → Account
# 2. Store balance.
# 3. Savings → interest.
# 4. Current → overdraft.
# 5. FixedDeposit → maturity.
# 6. Show each separately.

# %%
class Bank:
    def __init__(self, balance):
        self.balance = balance
class Savings(Bank):
    def cal_interest(self):
        interest = self.balance * 0.05
        print("Interest:", interest)
class Current(Bank):
    def show_overdraft(self):
        print("Overdraft Limit: 10000")
class FixedDeposit(Bank):
    def cal_maturity(self):
        maturity = self.balance + (self.balance * 0.50)
        print("Maturity Amount:", maturity)
s = Savings(10000)
print("Savings Account")
print("Balance:", s.balance)
s.cal_interest()
print()
c = Current(20000)
print("Current Account")
print("Balance:", c.balance)
c.show_overdraft()
print()
f = FixedDeposit(1000)
print("Fixed Deposit Account")
print("Balance:", f.balance)
f.cal_maturity()
# Out:
# Savings Account
# Balance: 10000
# Interest: 500.0
#
# Current Account
# Balance: 20000
# Overdraft Limit: 10000
#
# Fixed Deposit Account
# Balance: 1000
# Maturity Amount: 1500.0

# %% [markdown]
# 25. Vehicle System
# Concept
# Common parent with specialized children.
# How to Solve
# 1. Parent → Vehicle
# 2. TwoWheeler adds helmet method.
# 3. FourWheeler adds seatbelt method.
# 4. Demonstrate both.

# %%
class Vehicle:
    def __init__(self, brand):
        self.brand = brand
    def start(self):
        print(self.brand, "vehicle is started")
class Two_wheeler(Vehicle):
    def helmet(self):
        print("Wear a helmet")
class Four_wheeler(Vehicle):
    def seatbelt(self):
        print("Wear a seatbelt")
t = Two_wheeler("Honda")
f = Four_wheeler("Toyota")
t.start()
t.helmet()
f.start()
f.seatbelt()
# Out:
# Honda vehicle is started
# Wear a helmet
# Toyota vehicle is started
# Wear a seatbelt

# %% [markdown]
# 26. Animal System
# Concept
# Method overriding.
# How to Solve
# 1. Parent method eat().
# 2. Herbivore overrides.
# 3. Carnivore overrides.
# 4. Show different outputs.

# %%
class Animal:
    def eat(self):
        print("Animal eats food")
class Herbivore(Animal):
    def eat(self):
        print("Herbivore eats plants")
class Carnivore(Animal):
    def eat(self):
        print("Carnivore eats meat")
h = Herbivore()
c = Carnivore()
h.eat()
c.eat()
# Out:
# Herbivore eats plants
# Carnivore eats meat

# %% [markdown]
# 27. Employee Salary
# Concept
# Different salary calculations.
# How to Solve
# 1. Parent stores common data.
# 2. FullTime calculates monthly salary.
# 3. PartTime calculates hourly salary.
# 4. Override calculation method.

# %%
class Employee:
    def __init__(self, name):
        self.name = name
    def calculate_salary(self):
        print("Salary calculation")
class FullTime(Employee):
    def __init__(self, name, monthly_salary):
        super().__init__(name)
        self.monthly_salary = monthly_salary
    def calculate_salary(self):
        print("Employee:", self.name)
        print("Monthly Salary:", self.monthly_salary)
class PartTime(Employee):
    def __init__(self, name, hours, hourly_rate):
        super().__init__(name)
        self.hours = hours
        self.hourly_rate = hourly_rate
    def calculate_salary(self):
        salary = self.hours * self.hourly_rate
        print("Employee:", self.name)
        print("Hourly Salary:", salary)
f = FullTime("Aks", 50000)
p = PartTime("kams", 80, 500)
f.calculate_salary()
p.calculate_salary()
# Out:
# Employee: Aks
# Monthly Salary: 50000
# Employee: kams
# Hourly Salary: 40000

# %% [markdown]
# 28. Shape Hierarchy
# Concept
# One parent with multiple children.
# How to Solve
# 1. Parent → Shape
# 2. Child → 2DShape
# 3. Child → 3DShape
# 4. Each has its own methods.
# 5. Show both inherit from Shape.

# %%
class Shape:
    def display(self):
        print("This is a shape")
class twoD(Shape):
    def area(self):
        print("Calculating area")
class threeD(Shape):
    def volume(self):
        print("Calculating volume ")
TWOd = twoD()
THREEd = threeD()
TWOd.display()
TWOd.area()
THREEd.display()
THREEd.volume()
# Out:
# This is a shape
# Calculating area
# This is a shape
# Calculating volume

# %% [markdown]
# 29. Notification System
# Concept
# Method overriding.
# How to Solve
# 1. Parent → Notification
# 2. Method send()
# 3. Email overrides.
# 4. SMS overrides.
# 5. Push overrides.
# 6. Call send() using each object.

# %%
class Notification:
    def send(self):
        print("Sending notification")
class Email(Notification):
    def send(self):
        print("Sending Email")
class SMS(Notification):
    def send(self):
        print("Sending SMS")
class Push(Notification):
    def send(self):
        print("Sending Push Notification")
email = Email()
sms = SMS()
push = Push()
email.send()
sms.send()
push.send()
# Out:
# Sending Email
# Sending SMS
# Sending Push Notification

# %% [markdown]
# 30. Your Own Hierarchical Design
# Concept
# Complete hierarchical inheritance program.
#
# Sumit Sir Notes
# How to Solve
# 1. Choose one parent class.
# 2. Add common attributes.
# 3. Add common methods.
# 4. Create three child classes.
# 5. Add child-specific methods.
# 6. Create objects of all child classes.
# 7. Show that every child can:
# o Access parent attributes.
# o Access parent methods.
# o Use its own methods independently.

# %%
class Vehicle:
    def __init__(self, brand, color):
        self.brand = brand
        self.color = color
    def start(self):
        print(self.brand, "vehicle is started")
class Car(Vehicle):
    def open_trunk(self):
        print("Car trunk is opened")
class Bike(Vehicle):
    def wear_helmet(self):
        print("Wear helmet")
class Bus(Vehicle):
    def open_door(self):
        print("Bus door is opened")
c = Car("Toyota", "White")
b = Bike("Honda", "Black")
bu = Bus("Volvo", "Blue")
print("Brand:", c.brand)
print("Color:", c.color)
c.start()
c.open_trunk()
print("Brand:", b.brand)
print("Color:", b.color)
b.start()
b.wear_helmet()
print("Brand:", bu.brand)
print("Color:", bu.color)
bu.start()
bu.open_door()
# Out:
# Brand: Toyota
# Color: White
# Toyota vehicle is started
# Car trunk is opened
# Brand: Honda
# Color: Black
# Honda vehicle is started
# Wear helmet
# Brand: Volvo
# Color: Blue
# Volvo vehicle is started
# Bus door is opened
