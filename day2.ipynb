# %%
#LOGICAL OPERATORS

A=int(input("enter age:"))
B=int(input("marks:"))
if A>=18 and A<=25 and B>=60:
        print("eligible for admission")
else:
        print("not eligible for admission")
# Out:
# enter age: 25
# marks: 61
# eligible for admission

# %%
A=str(input("enter username:"))
B=int(input("password:"))
if A == "admin" and B == 12345:
    print("login successful")
else:
    print("login failed")
# Out:
# enter username: admin
# password: 12345
# login successful

# %%
n=int(input("enter a value:"))
if n >= 50 and n <= 100 and n % 5 != 0:
    print("num is bet 50 and 100 and not divisible by 5")
else:
    print("condition not satisfied")
# Out:
# enter a value: 60
# condition not satisfied

# %%
a=int(input("enter value:")
b=int(input("enter value:")
c=int(input("enter value:")
if a > b and a > c:
    print("a is largest")
elif b > a and b > c:
    print("b is largest")
else:
    print("c is largest")
# Out:
# enter a value: 20
# enter a value: 10
# enter a value: 30
# c is largest

# %%
a=str(input("enter name:"))
print(a.upper())
print(a.lower())
print(len(a))
print(a[:3])
print(a[14:])
# Out:
# enter name: akshitha nayineni
# AKSHITHA NAYINENI
# akshitha nayineni
# 17
# aks
# eni

# %%
s=str(input("enter a sentences:"))
print(s[:10])
print(s[-10:])
print(s[5:16])
print(s[::2])
# Out:
# enter a sentences: pythonprogramming
# pythonprog
# rogramming
# nprogrammin
# ptopormig

# %%
w=str(input("enter a word:"))
rev = w[::-1]
if w == rev:
    print("palindrome")
else:
    print("not palindrome")
# Out:
# enter a word: radar
# palindrome

# %%
email=input("enter email:")
parts=email.split("@")
print("username:",parts[0])
print("domain:",parts[1])
# Out:
# enter email: akshitharao@gmail.com
# username: akshitharao
# domain: gmail.com

# %%
p=input("enter password:")
if len(p) >= 8 and ("@" in p or "#" in p):
    print("strong password")
else:
    print("weak password")
# Out:
# enter password: Akshitha@1
# strong password

# %%
eng=int(input("enter marks of eng:"))
math=int(input("enter marks of math:"))
sci=int(input("enter marks of sci:"))
if eng>=40 and math>=40 and sci>=40:
        print("student passed")
else:
        print("student failed")
# Out:
# enter marks: 20
# enter marks: 30
# enter marks: 40
# student failed

# %%
n=int(input("enter value"))
if n > 0 and n % 2 == 0:
    print("positive and even")
elif n < 0 or n % 2 != 0:
    print("negative or odd")
# Out:
# enter value -19
# negative or odd

# %%
cityname=str(input("enter city name"))
print(cityname[::-1])
count=(cityname.count("a")+cityname.count("e")+cityname.count("i")+cityname.count("o")+cityname.count("u")+cityname.count("u")+cityname.count("A")+cityname.count("E")+cityname.count("I")+cityname.count("O")+cityname.count("U"))
print("no of vowels:",count)
print(cityname[1:-1])
# Out:
# enter city name warangal
# lagnaraw
# no of vowels: 3
# aranga

# %%
n=input("enter mobile num:")
print(n[:3])
print(n[6:])
print(n[3:6])
# Out:
# enter mobile num: 8332043333
# 833
# 3333
# 204

# %%
a=str(input("enter string:"))
if len(a) > 5 and a[0] == A or a:
    print("valid string")
else:
    print("invalid string")
# Out:
# enter string: akshitha
# valid string
