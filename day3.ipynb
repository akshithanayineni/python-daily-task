# %%
#slicing
a=input("enter the string:")
print(a[:5])
# Out:
# enter the string: akshitha
# akshi

# %%
a="akshitha"
print(a[-4:])
# Out:
# itha

# %%
a="myfullnameisakshitharaonayineni"
print(a[2:8])
# Out:
# fullna

# %%
a="myfullnameisakshitharaonayineni"
print(a[::2])
# Out:
# mflnmiasihroaiei

# %%
b="aksh rao nayineni"
part=b.split()
print("first name:",part[0])
print("last name:",part[2])
# Out:
# first name: aksh
# last name: nayineni

# %%
#case conversion 
a="my full name is akshitha rao nayineni"
print(a.upper())
print(a.lower())
print(a.title())
print(a.capitalize())
# Out:
# MY FULL NAME IS AKSHITHA RAO NAYINENI
# my full name is akshitha rao nayineni
# My Full Name Is Akshitha Rao Nayineni
# My full name is akshitha rao nayineni

# %%
a="my full name is akshitha rao nayineni"
b=a.title()
print(a)
print(b)
# Out:
# my full name is akshitha rao nayineni
# My Full Name Is Akshitha Rao Nayineni

# %%
a="123fULLStAcK"
print(a)
print(a.islower())
print(a.isupper())
print(a)
# Out:
# 123fULLStAcK
# False
# False
# 123fULLStAcK

# %%
a="123fULLStAcK"
print(a.isalpha())
# Out:
# False

# %%
a=input("enter the string:")
print(a.isdigit())
# Out:
# enter the string: 12345
# True

# %%
a=input("enter the string:")
print(a.isalnum())
# Out:
# enter the string: 1234r
# True

# %%
a=input("enter the string:")
print(a.islower())
# Out:
# enter the string: lower
# True

# %%
password=input("enter the string:")
if password.isalnum and len(password)>=8:
    print("valid password")
else:
    print("invallid password")
# Out:
# enter the string: akshitha@1
# valid password

# %% [markdown]
# #find() and index() questions

# %%
a="akshitha"
ch="s"
index=a.find(ch)
print(index)
# Out:
# 2

# %%
a="my name is abcd"
word="abcd"
c=a.find(word)
if c != 1:
    print("-1")
else:
    print("exists")
# Out:
# -1

# %%
a="python programming language"
b=a.index(("python"))
print(b)
# Out:
# 0

# %%
a="python"
print(a.find("n"))
print(a.index("n"))
# Out:
# 5
# 5

# %%
a="nayineni akshitha"
b=a.upper()
space=b.find(" ")
firstname = b[:space]
lastname = b[space+1:]
print("fistname:",firstname)
print("lastname:",lastname)
print(space)
# Out:
# fistname: NAYINENI
# lastname: AKSHITHA
# 8

# %%
a="8332043333"
if a.isdigit() and len(a)==10:
    print("contains 10 digits and length>10")
else:
    print("no")
# Out:
# contains 10 digits and length>10

# %%
a="kamalakar"
print(a[::-1])
print(a.title())
if a==a[::-1]:
    print("palindrome")
else:
    print("not palindrome")
# Out:
# rakalamak
# Kamalakar
# not palindrome
