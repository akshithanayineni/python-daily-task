# %%
a=int(input())
if a>0:
    print("positive")
else: 
    print("negative")
# Out:
#  3
# positive

# %%
age=int(input())
if age>=18:
    print("you can vote")
else:
    print("no")
# Out:
#  24
# you can vote

# %% [markdown]
# #larger number

# %%
a=int(input())
b=int(input())
if a>b:
    print("a is larger")
else:
    print("b is larger")
# Out:
#  21
#  89
# b is larger

# %% [markdown]
# #even or odd

# %%
a=int(input())
if a%2==0:
    print("it is even")
else:
    print("it is odd")
# Out:
#  1
# it is odd

# %%
ch=input("enter a character:")
if ch=="A":
    print("it is 'A' ")
else:
    print("not")
# Out:
# enter a character: A
# it is 'A'

# %%
marks=99
if marks>=40:
    print("pass")
else:
    print("no")
# Out:
# pass

# %% [markdown]
# #divisible by 5

# %%
a=int(input())
if a%5==0:
    print("it is divisible by 5")
else:
    print("it is not divisible by 5")
# Out:
#  50
# it is divisible by 5

# %% [markdown]
# #medium level

# %%
a=100
if a>0:
    print("positive")
elif a<0:
    print("negative")
else:
    print("0")
# Out:
# positive

# %% [markdown]
# #largest of 3

# %%
a=int(input())
b=int(input())
c=int(input())
if a>b and a>c:
    print("a is largest")
elif b>a and b>c:
    print("b is largest")
else:
    print("c is largest")
# Out:
#  2
#  3
#  4
# c is largest

# %%
year=2000
if (year%4==0 and year%100!=0) or year%400==0:
    print("its leap year")
else:
    print("no")
# Out:
# its leap year

# %%
ch=input("enter a character:")
if ch in"aeiouAEIOU":
    print("vowel")
else:
    print("consonant")
# Out:
# enter a character: a
# vowel

# %%
salary=int(input("enter the salary"))
if salary>50000:
    print("high")
elif salary>30000:
    print("medium")
else:
    print("low")
# Out:
# enter the salary 30000
# low

# %%
t=int(input("enter temperature in Celsius"))
if t>30:
      print("hot")
elif t>20 and t<30:
      print("warm")
else:
     print("cold")
# Out:
# enter temperature in Celsius 40
# hot

# %%
num=300
if num%3==0 and num%5==0:
    print("FizzBuzz")
elif num%3==0:
    print("Fizz")
elif num%5==0:
    print("Buzz")
else:
    print("the num",num)
# Out:
# FizzBuzz

# %%
age=20
gender="female"
if age >= 18 and gender=="Male":
    print("Eligible for Army")
elif age >= 18 and gender=="female":
    print("Eligible for Other Services")
else:
    print("not Eligible")
# Out:
# Eligible for Other Services

# %%
ch=input("enter a character:")
if ch.islower():
    print("lowercase")
elif ch.isupper():
    print("uppercase")
elif ch.isdigit():
    print("digit")
else:
    print("special character")
# Out:
# enter a character: @
# special character

# %%
a=int(input())
b=int(input())
c=int(input())
if a<b and a<c and b<c:
    print("ascending order is:",(a,b,c))
elif a<b and a<c and c<b:
    print("ascending order is",(a,c,b))
elif b<a and b<c and a<c:
    print("ascending order is",(b,a,c))
elif b<c and b<a and c<a:
    print("ascending order is",(b,c,a))
elif c<b and c<a and a<b:
    print("ascending order is",(c,a,b))
else:
    print("ascending order is",(c,b,a))
# Out:
#  5
#  6
#  3
# ascending order is (3, 5, 6)

# %%
n=int(input())
if n%2==0:
    print("divisible by 2")
else:
    print("not divisible by 2")
# Out:
#  4
# divisible by 2

# %%
t=int(input())
if t<12:
    print("morning")
elif t>12 and t<17:
    print("aft")
else:
    print("evng")
# Out:
#  20
# evng

# %%
u=int(input())

if u<=100:
    bill=2*u
    
elif u>=100 and u<=300:
    bill=4*u
else:
    bill=6*u
print("bill:",bill)
# Out:
#  300
# bill: 1200

# %%
a=int(input())
if a%3==0 and a%5==0:
    print("multiple of 3 and 5")
elif a%3==0 and a%5!=0:
    print("multiple of only 3")
elif a%3!=0 and a%5==0:
    print("multiple of only 5")
else:
    print("none")
# Out:
#  23
# none

# %%
balance=1000
choice=int(input("enter choice:"))
if choice==1:
    print("balance amount:",balance)
elif choice==2:
      amount=int(input())
      if amount<=balance:
        balance=balance-amount
        print("remaining balance:",balance)
      else:
        print("not suff")
elif choice==3:
     amount=int(input())
     balance=balance+amount
     print("balance:",balance)
else:
     print("invalid")
# Out:
# enter choice: 2
#  2000
# not suff

# %%
salary=int(input("enter salary"))
if salary>=50000:
    bonus=(salary*20)/100
elif salary>=30000 and salary<=50000:
    bonus=(salary*10)/100
else:
    bonus=(salary*5)/100
print("bonus:",bonus)
# Out:
# enter salary 3500
# bonus: 175.0

# %%
income=int(input("enter income"))
if income<250000:
   tax=0
elif income<=500000:
    tax=income*5/100
elif income<=1000000:
    tax=income*20/100
else:
    tax=income*30/100
print("income tax:",tax)
# Out:
# enter income 600000
# income tax: 120000.0

# %%
a=int(input())
b=int(input())
c=int(input())
d=b**2 - 4*a*c
if d>0:
    print("two distinct real roots")
elif d==0:
    print("two equal real roots")
else:
    print("two imaginary roots")
# Out:
#  1
#  2
#  3
# two imaginary roots

# %% [markdown]
# #simple calculator

# %%
a=int(input())
b=int(input())
choice=int(input("enter the choice:"))
if choice==1:
    print("addition:",a+b)
elif choice==2:
    print("subtraction:",a-b)
elif choice==3:
    print("multiplication:",a*b)
elif choice==4:
    print("division:",a/b)
else:
    print("invalid")
# Out:
#  2
#  3
# enter the choice: 1
# addition: 5

# %% [markdown]
# #season based on month num

# %%
month=int(input("enter the num:"))
if month==12 or month==1 or month==2:
    print("winter")
elif month==3 or month==4 or month==5:
    print("summer")
elif month==6 or month==7 or month==8:
    print("monsoon")
else:
    print("autumn")
# Out:
# enter the num: 9
# autumn

# %%
p=int(input("enter the num:"))
if p>5000:
    d=p*30/100
elif p>2000 and p<5000:
    d=p*20/100
else:
    d=p*10/100
print("discount:",d)
# Out:
# enter the num: 3000
# discount: 600.0
