# %%
a="akshitha rao nayineni"
a.replace(" ","_")
# Out:
# 'akshitha_rao_nayineni'

# %%
a=" hello mam "
print(a.strip())
# Out:
# hello mam

# %%
a="welcome to hyderabad"
print(a.startswith("hello"))
# Out:
# False

# %%
a="akshitharao3333@gmail.com"
print(a.endswith(".com"))
# Out:
# True

# %%
a="apple,banana,mango"
print(a.split())
# Out:
# ['apple,banana,mango']

# %%
a=["apple","banana","grapes","mango","pineapple"]
(" ".join(a))
# Out:
# 'apple banana grapes mango pineapple'

# %%
List=[" python "," is "," awesome "]
List[0].strip() + " " + List[1].strip() + " " + List[2].strip()
("".join(List))
# Out:
# ' python  is  awesome '

# %%
name="akshitha rao nayineni"
parts=name.split(" ")
print("first name is",parts[0])
print("last name is",parts[-1])
# Out:
# first name is akshitha
# last name is nayineni

# %%
a=input("enter the sentence")
b=a.split(" ")
print(b)
print(len(b))
# Out:
# enter the sentence my name is aksh
# ['my', 'name', 'is', 'aksh']
# 4

# %%
a="akshitharao345@gmail.com"
print(a.endswith("@gmail.com"))
# Out:
# True

# %%
a="helloo world python"
b=a.replace("world","everyone")
print(b)
b.split()
# Out:
# helloo everyone python
# ['helloo', 'everyone', 'python']

# %%
c1=input()
c2=input()
c3=input()
c4=input()
c5=input()
a=[c1,c2,c3,c4,c5]
b=("\n".join(a))
print(b)
# Out:
#  hyderabad
#  warangal
#  khammam
#  hanamkonda
#  vizag
# hyderabad
# warangal
# khammam
# hanamkonda
# vizag

# %%
a=" hello world "
b=a.strip()

print(a.title())
# Out:
#  Hello World

# %%
a="she is bad girl"
b=a.split()
(" ".join(b))
b=a.replace("bad","good")
print(b)
# Out:
# she is good girl

# %%
List=["10","20","30","40"]
("-".join(List))
# Out:
# '10-20-30-40'

# %%
#hard level
a="my name is akshitharao"
b=a.replace(" ","-")
print(b)
c=b.split("-")
if len(c[0])>4:
    print(c[0])
elif len(c[1])>4:
    print(c[1])
elif len(c[2])>4:
    print(c[2])
elif len(c[3])>4:
    print(c[3])
# Out:
# my-name-is-akshitharao
# akshitharao

# %%
a="my name is akshitharao"
b=a.split(" ")
c=[]
for i in b:
# Out:
#   Cell In[5], line 4
#     if a[0].startswith(("a","e","i,"o","u","A","E","I","O","U")):
#                                                             ^
# SyntaxError: unterminated string literal (detected at line 4)

# %%
List=["akshu","pinky","varsh","hari","kamalakar"]
a=(",".join(List))
print(a)
a.replace("akshu","new student")
# Out:
# akshu,pinky,varsh,hari,kamalakar
# 'new student,pinky,varsh,hari,kamalakar'

# %%
a=" my name fav color is purple "
c=a.replace("purple","black")
print(c)
d=a.strip()
print(d)
e=a.split()
print(e)
b=(" ".join(a))
print(b)
# Out:
#  my name fav color is black
# my name fav color is purple
# ['my', 'name', 'fav', 'color', 'is', 'purple']
#   m y   n a m e   f a v   c o l o r   i s   p u r p l e

# %%
a=input("enter paragraph:")
b=a.split(".")
b[0]=b[0].strip()
b[1]=b[1].strip()
b[2]=b[2].strip()
print("\n".join(b))
# Out:
# enter paragraph: my name is aksh.i love dance.my fav color is black.
# my name is aksh
# i love dance
# my fav color is black
