# %%
dict1={"name":"aksh","age":20,"city":"warangal"}
print(dict1)
# Out:
# {'name': 'aksh', 'age': 20, 'city': 'warangal'}

# %% [markdown]
# #keys

# %%
d = {"a": 1, "b": 2, "c": 3}
d.keys()
# Out:
# dict_keys(['a', 'b', 'c'])

# %% [markdown]
# #values

# %%
d = {"a": 1, "b": 2}
d.values()
# Out:
# dict_values([1, 2])

# %% [markdown]
# #get()

# %%
d = {"name": "Sumit", "age": 25}
d.get("name")
# Out:
# 'Sumit'

# %% [markdown]
# #tup

# %%
tup=(1,2,3,4,5)
print(type(tup))
print(len(tup))
# Out:
# <class 'tuple'>
# 5

# %% [markdown]
# #count

# %%
tup = (10, 20, 30, 40, 50)
print(tup.count(20))
# Out:
# 1

# %% [markdown]
# #index

# %%
tup=(10, 20, 30, 40)
print(tup.index(30))
# Out:
# 2

# %%
dict1={}
dict1["a"]=10
dict1["b"]=10
dict1["c"]=10
print(dict1)
# Out:
# {'a': 10, 'b': 10, 'c': 10}

# %% [markdown]
# #update

# %%
d = {"a": 1, "b": 2}
d.update({"c": 3, "d": 4})
print(d)
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %% [markdown]
# #remove

# %%
student = {"name": "Rahul",
           "age": 22, "city": "Delhi"}
student.pop("age")
print(student)
# Out:
# {'name': 'Rahul', 'city': 'Delhi'}

# %% [markdown]
# #popitem

# %%
d = {"x": 10, "y": 20, "z": 30}
a=d.popitem()
print(a)
# Out:
# ('z', 30)

# %% [markdown]
# #copy

# %%
dict1 = {"a": 1, "b": 2}
dict2 = dict1.copy()
print("original:",dict1)
print("copy:",dict2)
# Out:
# original: {'a': 1, 'b': 2}
# copy: {'a': 1, 'b': 2}

# %% [markdown]
# #fromkeys

# %%
keys=["red", "green","blue"]
dict1=dict.fromkeys(keys,0)
print(dict1)
# Out:
# {'red': 0, 'green': 0, 'blue': 0}

# %%
tup=(1,2.2,"aksh")
tup.replace(1,2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[27], line 2
#       1 tup=(1,2.2,"aksh")
# ----> 2 tup.replace(1,2)
#
# AttributeError: 'tuple' object has no attribute 'replace'

# %%
d = {"name": "Sumit"}
d.setdefault("age", 25)
print(d)
# Out:
# {'name': 'Sumit', 'age': 25}

# %%
dict1 = {}
dict1.update({"b":2, "c":3, "d":4 })
print(dict1)
dict1.popitem()
print(dict1)
# Out:
# {'b': 2, 'c': 3, 'd': 4}
# {'b': 2, 'c': 3}

# %%
tup=(1,2,3,7,5,6,7)
print(tup.index(7))
print(tup.count(7))
# Out:
# 3
# 2

# %% [markdown]
# #3 student marks

# %%
dict4={}
name1=input()
marks1=int(input())
dict4[name1]=marks1
name2=input()
marks2=int(input())
dict4[name2]=marks2
name3=input()
marks3=int(input())
dict4[name3]=marks3
print(dict4)
# Out:
#  aksh
#  79
#  ram
#  90
#  sam
#  87
# {'aksh': 79, 'ram': 90, 'sam': 87}

# %%
dict1=d = {"x": 10, "y": 20, "z": 30, "a":25, "b":65}
dict2=dict1.copy()
print("dict2:",dict2)
dict1.clear()
print(dict1)
# Out:
# dict2: {'x': 10, 'y': 20, 'z': 30, 'a': 25, 'b': 65}
# {}

# %%
data = {"a": 10, "b": 20, "c": 10}
data.items()
print(data)
c=data.fromkeys(keys,10)
data.remove({"b":20})
# Out:
# {'a': 10, 'b': 20, 'c': 10}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[56], line 5
#       3 print(data)
#       4 c=data.fromkeys(keys,10)
# ----> 5 data.remove({"b":20})
#
# AttributeError: 'dict' object has no attribute 'remove'

# %% [markdown]
# #level-hard

# %%
dict1={"name1":"somesh","name2":"rakesh","name4":"anu","name5":"rinku"}
dict1.update({"name6":"akhila"})
print(dict1)
dict1.popitem()
print(dict1)
# Out:
# {'name1': 'somesh', 'name2': 'rakesh', 'name4': 'anu', 'name5': 'rinku', 'name6': 'akhila'}
# {'name1': 'somesh', 'name2': 'rakesh', 'name4': 'anu', 'name5': 'rinku'}

# %%
tup=(1,2,3,4,5,25,7,8)
print(tup.index(25))
print(tup.count(25))
a=list(tup)
print(a)
a.sort(reverse=True)
print(a)
# Out:
# 5
# 1
# [1, 2, 3, 4, 5, 25, 7, 8]
# [25, 8, 7, 5, 4, 3, 2, 1]

# %%
name1=input()
marks1=int(input())
name2=input()
marks2=int(input())
name3=input()
marks3=int(input())
name4=input()
marks4=int(input())
dict5={name1:marks1,name2:marks2,name3:marks3,name4:marks4}
if marks1 > marks2 and marks1 > marks3 and marks1 > marks4:
    print("highest marks:",name1)
elif marks2 >marks1 and marks2 > marks3 and marks2 > marks4:
    print("highest marks:",name2)
elif marks3 >marks1 and marks3 > marks2 and marks3 > marks4:
    print("highest marks:",name3)
else:
    print("highest marks:",name4)
# Out:
#  aksh
#  56
#  ram
#  57
#  sam
#  89
#  rom
#  32
# highest marks: sam

# %%
info = {"name": "Aman", "age": 21, "city":"Mumbai"}
info1=info.copy()
print("info1:",info1)
info1.update({"country":"india"})
print(info1)
print(info)
# Out:
# info1: {'name': 'Aman', 'age': 21, 'city': 'Mumbai'}
# {'name': 'Aman', 'age': 21, 'city': 'Mumbai', 'country': 'india'}
# {'name': 'Aman', 'age': 21, 'city': 'Mumbai'}

# %%
data = (10, 20, 30, 20, 40, 20, 50)
d6={}
d6[10]=data.count(10)
d6[20]=data.count(20)
d6[30]=data.count(30)
d6[40]=data.count(40)
d6[50]=data.count(50)
print(d6)
# Out:
# {10: 1, 20: 3, 30: 1, 40: 1, 50: 1}

# %%
data={"a":10,"b":20,"c":10}
for i,j in data.items():
    if j==10:
        print(f"{i}:{j}")
# Out:
# a:10
# c:10
