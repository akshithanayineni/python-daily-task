# %%
# nayineni Akshitha,SR University,electronics and communication Engineering

# %%
# Nayineni Akshitha
# SR University
# Electronics and Communication Engineering

# %%
""" Nayineni Akshitha, SR University, Electronics and communication engineering """
# Out:
# ' Nayineni Akshitha, SR University, Electronics and communication engineering '

# %%
# identation Practice
if True:
    print("Hello World")
    print("Welcome to Python")
# Out:
# Hello World
# Welcome to Python

# %%
# Variable Declaration
name = "Akshitha"
age = 21
height = 5.4
is_student = True
print(type(name))
print(type(age))
print(type(height))
print(type(is_student))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
# stname
# myname
# totalamount
# class1
# myVar
# _score
# marks99

# %%
A = int(input("Enter the value of A:"))
B = int(input("Enter the value of B:"))
print(A + B)
print(A - B)
print(A * B)
print(A / B)
print(A // B)
print(A % B)
# Out:
# Enter the value of A: 10
# Enter the value of B: 20
# 30
# -10
# 200
# 0.5
# 0
# 10

# %%
A = int(input("Enter the value of A:"))
B = int(input("Enter the value of B:"))
print(A > B)
print(A < B)
print(A >= B)
print(A <= B)
print(A != B)
# Out:
# Enter the value of A: 20
# Enter the value of B: 60
# False
# True
# False
# True
# True

# %%
a = 10
a+=10
print(a)
a-=10
print(a)
a*=10
print(a)
a/=10
print(a)
a//=10
print(a)
a%=10
print(a)
a**=10
print(a)
# Out:
# 20
# 10
# 100
# 10.0
# 1.0
# 1.0
# 1.0

# %%
college = "SR University"
def details():
     name = "Akshitha"
     print(name,college)
details()
# Out:
# Akshitha SR University

# %%
a = float(input("Enter the value of temparature :"))
f=(a*(9/5))+32
print(f)
c=(f-32)*(5/9)
print(c)
# Out:
# Enter the value of temparature : 20
# 68.0
# 20.0

# %%
Age = int(input("Enter the Age:"))
Salary = int(input("Enter the Salary:"))
if(Age>=18 and Age<=60):
    if(Salary>25000):
        print("eligible for loan")
    else:
        print("not eligible for loan")
# Out:
# Enter the Age: 30
# Enter the Salary: 26000
# eligible for loan

# %%
sub1=int(input("enter the marks:"))
sub2=int(input("enter the marks:"))
sub3=int(input("enter the marks:"))
sub4=int(input("enter the marks:"))
sub5=int(input("enter the marks:"))
total=sub1+sub2+sub3+sub4+sub5
percentage=(total/500)*100
if (percentage>=90):
    print("A+")
elif(percentage>=80):
    print("A")
elif(percentage>=70):
    print("B")
else:
    print("c")
# Out:
# enter the marks: 60
# enter the marks: 70
# enter the marks: 80
# enter the marks: 90
# enter the marks: 100
# A

# %%
r=int(input("enter the value:"))
pi=3.14
A=pi*(r*r) 
c=2*pi*r
print(A)
print(c)
# Out:
# enter the value: 3
# 28.26
# 18.84

# %% [markdown]
# # swapping numbers with nd without variable

# %%
a=int(input("enter value:"))
b=int(input("enter value:"))
temp=a
a=b
b=temp
print(a,b)
# Out:
# enter value: 20
# enter value: 10
# 10 20

# %%
a=int(input("enter value:"))
b=int(input("enter value:"))
a,b = b,a
print("a=",a)
print("b=",b)
# Out:
# enter value: 10
# enter value: 20
# a= 20
# b= 10

# %% [markdown]
# #dynamic typing

# %%
x=10
print(str(x))
print(type(str(x)))
print(float(x))
print(type(float(x)))
print(bool(x))
print(type(bool(x)))
# Out:
# 10
# <class 'str'>
# 10.0
# <class 'float'>
# True
# <class 'bool'>

# %%
a=int(input("enter value"))
b=int(input("enter value"))
choice=int(input("enter value"))
if choice == 1:
       print(a+b)
elif choice == 2:
       print(a-b)
elif choice == 3:
       print(a*b)
elif choice == 4:
       print(a/b)
elif choice == 5:
       print(a**b)
elif choice == 6:
       print(a*b)
elif choice == 7:
       print(a//b)
elif choice == 8:
       print(a%b)
else:
      print("invalid")
# Out:
# enter value 20
# enter value 40
# enter value 1
# 60
