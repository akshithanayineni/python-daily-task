# %%
from abc import ABC, abstractmethod
class Shape(ABC):
    @abstractmethod
    def calculate_area(self):
        pass
    @abstractmethod
    def calculate_perimeter(self):
        pass
class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius
    def calculate_area(self):
        return 3.14 * self.radius * self.radius
    def calculate_perimeter(self):
        return 2 * 3.14 * self.radius
class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width
    def calculate_area(self):
        return self.length * self.width

    def calculate_perimeter(self):
        return 2 * (self.length + self.width)
c = Circle(5)
print("Circle Area:", c.calculate_area())
print("Circle Perimeter:", c.calculate_perimeter())
r = Rectangle(10, 5)
print("Rectangle Area:", r.calculate_area())
print("Rectangle Perimeter:", r.calculate_perimeter())
# Out:
# Circle Area: 78.5
# Circle Perimeter: 31.400000000000002
# Rectangle Area: 50
# Rectangle Perimeter: 30

# %% [markdown]
# 2. Class Name: Vehicle
# Problem
# Create an abstract class named Vehicle.
# Explanation
# Every vehicle can start and stop, but each vehicle does it differently.
# Create two abstract methods:
# • start()
# • stop()
# Create a Car class that implements both methods.

# %%
from abc import ABC, abstractmethod
class vehicle(ABC):
    @abstractmethod
    def start(self):
        pass
    @abstractmethod
    def stop(self):
        pass
class car(vehicle):
    def start(self):
        print("car starts with key")
    def stop(self):
        print("car stops with brakes")

c=car()

c.start()
c.stop()
# Out:
# car starts with key
# car stops with brakes

# %% [markdown]
# 3. Class Name: Animal
# Problem
# Create an abstract class named Animal.
# Explanation
# Every animal makes a sound, but the sound depends on the animal.
# Create an abstract method:
# • make_sound()
# Create subclasses:
# • Dog
# • Cat
# Each should implement its own sound.

# %%
from abc import ABC, abstractmethod
class animal(ABC):
    @abstractmethod
    def sound(self):
        pass
class dog(animal):
    def sound(self):
        print("bowww")
class cat(animal):
    def sound(self):
        print("meoww")
c=cat()
d=dog()
c.sound()
d.sound()
# Out:
# meoww
# bowww

# %% [markdown]
# 4. Class Name: Payment
# Problem
# Create an abstract class named Payment.
# Explanation
# Every payment processes money differently.
# Create an abstract method:
# • process_payment(amount)
# Create subclasses:
# • CreditCard
# • Cash
# Each should process the payment in its own way.

# %%
from abc import ABC, abstractmethod
class payment(ABC):
    @abstractmethod
    def process_payment(self,amt):
        pass
class credit_card_payment(payment):
    def process_payment(self,amt):
        print("payment by credit card",amt)
class cash(payment):
    def process_payment(self,amt):
        print("payment by cash",amt)
c=credit_card_payment()
u=cash()
c.process_payment(30000)
u.process_payment(90000)
# Out:
# payment by credit card 30000
# payment by cash 90000

# %% [markdown]
# 5. Class Name: Report
# Problem
# Create an abstract class named Report.
# Explanation
# Different report formats generate reports differently.
# Create an abstract method:
# • generate()
# Create:
# • PDFReport
# • ExcelReport
# Each should generate the report differently.

# %%
from abc import ABC, abstractmethod
class report(ABC):
    @abstractmethod
    def generate_report(self):
        pass
class pdf_report(report):
    def generate_report(self):
        print("generate report in pdf")
class excel_report(report):
    def generate_report(self):
        print("generate report in excel")
p=pdf_report()
e=excel_report()
p.generate_report()
e.generate_report()
# Out:
# generate report in pdf
# generate report in excel

# %% [markdown]
# 6. Class Name: BankAccount
# Problem
# Create an abstract class named BankAccount.
# Explanation
# Different bank accounts calculate interest differently.
# Create an abstract method:
# • calculate_interest()
# Create:
# • SavingsAccount
# Implement the interest calculation.

# %%
from abc import ABC, abstractmethod
class bankacc(ABC):
    @abstractmethod
    def calculate_interest(self):
        pass
class savings_acc(bankacc):
    def __init__(self,balance):
        self.balance=balance
    def calculate_interest(self):
        return self.balance * 0.50
s=savings_acc(1000)
s.calculate_interest()
# Out:
# 500.0

# %% [markdown]
# 7. Class Name: Device
# Problem
# Create an abstract class named Device.
# Explanation
# Every electronic device can be turned on and off.
# Create abstract methods:
# • turn_on()
# • turn_off()
# Implement them in a subclass such as Laptop or TV.

# %%
from abc import ABC, abstractmethod
class Device(ABC):
    @abstractmethod
    def turn_on(self):
        pass
    @abstractmethod
    def turn_off(self):
        pass
class TV(Device):
    def turn_on(self):
        print("TV is turned ON")
    def turn_off(self):
        print("TV is turned OFF")
class Laptop(Device):
    def turn_on(self):
        print("Laptop is turned ON")
    def turn_off(self):
        print("Laptop is turned OFF")
t = TV()
l = Laptop()
t.turn_on()
t.turn_off()
l.turn_on()
l.turn_off()
# Out:
# TV is turned ON
# TV is turned OFF
# Laptop is turned ON
# Laptop is turned OFF

# %% [markdown]
# 8. Class Name: Employee
# Problem
# Create an abstract class named Employee.
# Explanation
# Employees receive bonuses based on their roles.
# Create an abstract method:
# • calculate_bonus()
# Create subclass:
# • Manager
# Implement the bonus calculation.

# %%
from abc import ABC, abstractmethod
class Employee(ABC):
    @abstractmethod
    def calculate_bonus(self):
        pass
class manager(Employee):
    def __init__(self, salary):
        self.salary = salary
    def calculate_bonus(self):
        return self.salary * 0.50
m = manager(50000)
print(m.calculate_bonus())
# Out:
# 25000.0

# %% [markdown]
# 9. Class Name: Transport
# Problem
# Create an abstract class named Transport.
# Explanation
# Every transport moves differently and uses different fuel.
# Create abstract methods:
# • move()
# • fuel_type()
# Create subclasses like:
# • Car
# • Train

# %%
from abc import ABC, abstractmethod

class Transport(ABC):
    @abstractmethod
    def move(self):
        pass
    @abstractmethod
    def fuel_type(self):
        pass
class car(Transport):
    def move(self):
        print("Car moves on the road")
    def fuel_type(self):
        print("Fuel Type: Petrol")
class train(Transport):
    def move(self):
        print("Train moves on railway tracks")
    def fuel_type(self):
        print("Fuel Type: Electricity")
c = car()
c.move()
c.fuel_type()

t = train()
t.move()
t.fuel_type()
# Out:
# Car moves on the road
# Fuel Type: Petrol
# Train moves on railway tracks
# Fuel Type: Electricity

# %% [markdown]
# 11. Class Name: FileHandler
# Problem
# Create an abstract class named FileHandler.
# Explanation
# Files can be read and written differently.
# Create abstract methods:
# • read()
# • write(data)
# Create subclasses like:
# • TextFileHandler
# • CSVFileHandler

# %%
from abc import ABC, abstractmethod
class FileHandler(ABC):
    @abstractmethod
    def read(self):
        pass
    @abstractmethod
    def write(self, data):
        pass
class TextFileHandler(FileHandler):
    def read(self):
        print("Read data from a text file.")
    def write(self, data):
        print("Write to text file:", data)
class CSVFileHandler(FileHandler):
    def read(self):
        print("Read data from a CSV file.")
    def write(self, data):
        print("Write to CSV file:", data)
text = TextFileHandler()
text.read()
text.write("honesty is the best policy")

csv = CSVFileHandler()
csv.read()
csv.write("my name is name")
# Out:
# Read data from a text file.
# Write to text file: honesty is the best policy
# Read data from a CSV file.
# Write to CSV file: my name is name

# %% [markdown]
# 12. Class Name: GameCharacter
# Problem
# Create an abstract class named GameCharacter.
# Explanation
# Every game character attacks differently.
# Create abstract method:
# • attack()
# Create subclasses:
# • Warrior
# • Mage

# %%
from abc import ABC, abstractmethod
class gamecharacter(ABC):
    @abstractmethod
    def attack(self):
        pass
class warrior(gamecharacter):
    def attack(self):
        print("Warrior attacks with a sword.")
class mage(gamecharacter):
    def attack(self):
        print("Mage attacks with magic spells.")
w = warrior()
m = mage()
w.attack()
m.attack()
# Out:
# Warrior attacks with a sword.
# Mage attacks with magic spells.

# %% [markdown]
# 13. Class Name: Calculator
# Problem
# Create an abstract class named Calculator.
# Explanation
# Different calculators perform different operations.
# Create abstract method:
# • compute(a, b)
# Create subclasses:
# • AdditionCalculator
# • MultiplicationCalculator

# %%
from abc import ABC, abstractmethod

class Calculator(ABC):
    @abstractmethod
    def compute(self, a, b):
        pass
class Add(Calculator):
    def compute(self, a, b):
        return a + b
class Multiply(Calculator):
    def compute(self, a, b):
        return a * b
add = Add()
mul = Multiply()
print(add.compute(10, 20))
print(mul.compute(10, 20))
# Out:
# 30
# 200

# %% [markdown]
# 14. Class Name: Database
# Problem
# Create an abstract class named Database.
# Explanation
# Different databases connect and execute queries differently.
# Create abstract methods:
# • connect()
# • query(sql)
# Create subclasses:
# • MySQLDatabase
# • MongoDatabase

# %%
from abc import ABC, abstractmethod
class database(ABC):
    @abstractmethod
    def connect(self):
        pass
    @abstractmethod
    def query(self, sql):
        pass
class MySQLDatabase(database):
    def connect(self):
        print("Connected to MySQL Database")
    def query(self, sql):
        print("Executing MySQL Query:", sql)
class MongoDatabase(database):
    def connect(self):
        print("Connected to MongoDB Database")
    def query(self, sql):
        print("Executing MongoDB Query:", sql)
mysql = MySQLDatabase()
mysql.connect()
mysql.query("SELECT * FROM students")
mongo = MongoDatabase()
mongo.connect()
mongo.query("db.students.find()")
# Out:
# Connected to MySQL Database
# Executing MySQL Query: SELECT * FROM students
# Connected to MongoDB Database
# Executing MongoDB Query: db.students.find()

# %% [markdown]
# 15. Class Name: Shape3D
# Problem
# Create an abstract class named Shape3D.
# Explanation
# Three-dimensional shapes have different formulas.
# Create abstract methods:
# • volume()
# • surface_area()
# Create subclasses:
# • Cube
# • Sphere

# %%
from abc import ABC, abstractmethod
class shape(ABC):
    @abstractmethod
    def volume(self):
        pass
    @abstractmethod
    def surface_area(self):
        pass
class cube(shape):
    def __init__(self, side):
        self.side = side
    def volume(self):
        return self.side ** 3
    def surface_area(self):
        return 6 * (self.side ** 2)
class sphere(shape):
    def __init__(self, radius):
        self.radius = radius
    def volume(self):
        return (4/3) * 3.14 * (self.radius ** 3)
    def surface_area(self):
        return 4 * 3.14 * (self.radius ** 2)

c = cube(4)
s = sphere(3)
print(c.volume())
print(c.surface_area())
print(s.volume())
print(s.surface_area())
# Out:
# 64
# 96
# 113.03999999999999
# 113.04
# 62.800000000000004
# 87.92

# %% [markdown]
# 10. Class Name: Notification
# Problem
# Create an abstract class named Notification.
# Explanation
# Notifications can be sent in different ways.
# Create abstract method:
# • send(message)
# Create subclasses:
# • EmailNotification
# • SMSNotification

# %%
from abc import ABC, abstractmethod
class Notification(ABC):
    @abstractmethod
    def send(self, message):
        pass
class EmailNotification(Notification):
    def send(self, message):
        print(f"Sending Email: {message}")
class SMSNotification(Notification):
    def send(self, message):
        print(f"SMS Notification: {message}")
Use super() to initialize the brand.
email = EmailNotification()
sms = SMSNotification()
print("Email Notification")
email.send("Welcome to our service!")
print("SMS Notification")
sms.send("Your OTP is 123456")
# Out:
# Email Notification
# Sending Email: Welcome to our service!
# SMS Notification
# Sending SMS: Your OTP is 123456

# %% [markdown]
# 16. Class Name: Shape
# Problem
# Create an abstract class named Shape.
# Explanation
# The constructor should accept a shape's color.
# __init__(self, color)
# Create an abstract method:
# • area()
# Create subclass:
# • Circle
# Use super() to initialize the color.

# %%
from abc import ABC, abstractmethod
class Shape(ABC):
    def __init__(self, color):
        self.color = color
    @abstractmethod
    def area(self):
        pass
class Circle(Shape):
    def __init__(self, color, radius):
        super().__init__(color)
        self.radius = radius
    def area(self):
        return 3.14 * self.radius ** 2
c = Circle("Red", 5)
print(c.color)
print(c.area())
# Out:
# Red
# 78.5

# %% [markdown]
# 17. Class Name: Vehicle
# Problem
# Create an abstract class named Vehicle.
# Explanation
# Store the vehicle brand in the constructor.
# __init__(self, brand)
# Create abstract methods:
# • start()
# • stop()
# Create subclass:

# %%
from abc import ABC, abstractmethod
class vehicle(ABC):
    def __init__(self, brand):
        self.brand = brand
    @abstractmethod
    def start(self):
        pass
    @abstractmethod
    def stop(self):
        pass
class car(vehicle):
    def __init__(self,brand):
        super().__init__(brand)
    def start(self):
        print("car started",{self.brand})
    def stop(self):
        print("car is stopped",{self.brand})
    
        
c= car("mahindra")
print("brand:",c.brand)
c.start()
c.stop()
# Out:
# brand: mahindra
# car started {'mahindra'}
# car is stopped {'mahindra'}

# %% [markdown]
# 18. Class Name: Animal
# Problem
# Create an abstract class named Animal.
# Explanation
# Store the animal's name in the constructor.
# __init__(self, name)
# Create abstract method:
# • make_sound()
# Create subclass:
# • Dog
# Use super() to initialize the name.

# %%
from abc import ABC, abstractmethod
class animal(ABC):
    def __init__(self, name):
        self.name = name
    @abstractmethod
    def make_sound(self):
        pass
class dog(animal):
    def __init__(self,name):
        super().__init__(name)
    def make_sound(self):
        print({self.name}," says bow")
    
        
d= dog("Dog")
print("name",d.name)
d.make_sound()
# Out:
# name Dog
# {'Dog'}  says bow

# %% [markdown]
# 19. Class Name: Payment
# Problem
# Create an abstract class named Payment.
# Explanation
# Store the payment amount in the constructor.
# __init__(self, amount)
# Create abstract method:
# • process_payment()
# Create subclasses:
# • CreditCard
# • Cash
# Use super() to initialize the amount.

# %%
from abc import ABC, abstractmethod

class payment(ABC):
    def __init__(self, amt):
        self.amt = amt
    @abstractmethod
    def process_payment(self):
        pass
class credit_card(payment):
    def __init__(self, amt):
        super().__init__(amt)
    def process_payment(self):
        print(self.amt, "amount paid by credit card")
class cash(payment):
    def __init__(self, amt):
        super().__init__(amt)
    def process_payment(self):
        print(self.amt, "amount paid by cash")
c1 = credit_card(3000)
c2 = cash(9000)
c1.process_payment()
c2.process_payment()
# Out:
# 3000 amount paid by credit card
# 9000 amount paid by cash

# %% [markdown]
# 20. Class Name: Employee
# Problem
# Create an abstract class named Employee.
# Explanation
# Store the employee name.
# __init__(self, name)
# Create abstract method:
# • calculate_bonus()
# Create subclass:
# • Manager
# Use super() to initialize the name.

# %%
from abc import ABC, abstractmethod

class employee(ABC):
    def __init__(self, name):
        self.name = name
    @abstractmethod
    def calculate_bonus(self):
        pass
class manager(employee):
    def __init__(self, name,salary):
        super().__init__(name)
        self.salary=salary
    def calculate_bonus(self):
        return self.salary * 0.20
    
        
e = manager("aks",40000)

print("bonus:",e.calculate_bonus())
# Out:
# bonus: 8000.0

# %% [markdown]
# 21. Class Name: Report
# Problem
# Create an abstract class named Report.
# Explanation
# Store the report title.
# __init__(self, title)
# Create abstract method:
# • generate()
# Create subclass:
# • PDFReport
# Use super() to initialize the title.

# %%
from abc import ABC, abstractmethod
class Report(ABC):
    def __init__(self, title):
        self.title = title
    @abstractmethod
    def generate(self):
        pass
class PDFReport(Report):
    def __init__(self, title):
        super().__init__(title)
    def generate(self):
        print(f"Generating PDF Report: {self.title}")
r = PDFReport("Monthly Report")
print("Report Title:", r.title)
r.generate()
# Out:
# Report Title: Monthly Report
# Generating PDF Report: Monthly Report

# %% [markdown]
# 22. Class Name: BankAccount
# Problem
# Create an abstract class named BankAccount.
# Explanation
#
# Store the account balance.
# __init__(self, balance)
# Create abstract method:
# • calculate_interest()
# Create subclass:
# • SavingsAccount
# Use super() to initialize the balance.

# %%
from abc import ABC, abstractmethod
class BankAccount(ABC):
    def __init__(self, balance):
        self.balance = balance
    @abstractmethod
    def calculate_interest(self):
        pass
class Savings_Acc(BankAccount):
    def __init__(self, balance):
        super().__init__(balance)
    def calculate_interest(self):
        interest = self.balance * 0.04   
        return interest
a = Savings_Acc(10000)
print(a.balance)
print(a.calculate_interest())
# Out:
# 10000
# 400.0

# %% [markdown]
# 23. Class Name: Device
# Problem
# Create an abstract class named Device.
# Explanation
# Store the device brand.
# __init__(self, brand)
# Create abstract methods:
# • turn_on()
# • turn_off()
# Create subclass:
# • Laptop
# Use super() to initialize the brand.

# %%
from abc import ABC, abstractmethod
class Device(ABC):
    def __init__(self, brand):
        self.brand = brand
    @abstractmethod
    def turn_on(self):
        pass
    @abstractmethod
    def turn_off(self):
        pass
class Laptop(Device):
    def __init__(self, brand):
        super().__init__(brand)
    def turn_on(self):
        print(f"{self.brand}, Laptop is turned on.")
    def turn_off(self):
        print(f"{self.brand}, Laptop is turned off.")
l = Laptop("hp")
print("Brand:", laptop.brand)
l.turn_on()
l.turn_off()
# Out:
# Brand: hp
# hp, Laptop is turned on.
# hp, Laptop is turned off.

# %% [markdown]
# 24. Class Name: Transport
# Problem
# Create an abstract class named Transport.
# Explanation
# Store the transport speed.
# __init__(self, speed)
# Create abstract methods:
# • move()
# • fuel_type()
# Create subclass:
# • Car
# Use super() to initialize the speed.

# %%
from abc import ABC, abstractmethod
class Transport(ABC):
    def __init__(self, speed):
        self.speed = speed
    @abstractmethod
    def move(self):
        pass
    @abstractmethod
    def fuel_type(self):
        pass
class Car(Transport):
    def __init__(self, speed):
        super().__init__(speed)
    def move(self):
        print(f"Car is moving at {self.speed}")
    def fuel_type(self):
        print("Fuel Type: Petrol")
car = Car(140)
print("Speed:", car.speed)
car.move()
car.fuel_type()
# Out:
# Speed: 140
# Car is moving at 140
# Fuel Type: Petrol

# %% [markdown]
# 25. Class Name: Notification
# Problem
# Create an abstract class named Notification.
# Explanation
# Store the recipient name.
# __init__(self, recipient)
# Create abstract method:
# • send(message)
# Create subclass:
# • EmailNotification
# Use super() to initialize the recipient.

# %%
from abc import ABC, abstractmethod
class Notification(ABC):
    def __init__(self, recipient):
        self.recipient = recipient
    @abstractmethod
    def send(self, message):
        pass
class EmailNotification(Notification):
    def __init__(self, recipient):
        super().__init__(recipient)
    def send(self, message):
        print(f"Email sent to {self.recipient}: {message}")
e = EmailNotification("aksh")
print("Recipient:", e.recipient)
e.send("Your account has been activated.")
# Out:
# Recipient: aksh
# Email sent to aksh: Your account has been activated.

# %% [markdown]
# 26. Class Name: Shape
# Problem
# Create an abstract class named Shape.
# Explanation
# Store the color in the constructor.
# Create abstract method:
# • area()
# Create subclass:
# • Rectangle
# Use super() to initialize the color and then calculate the area.

# %%
from abc import ABC, abstractmethod
class Shape(ABC):
    def __init__(self, color):
        self.color = color
    @abstractmethod
    def area(self):
        pass
class Rectangle(Shape):
    def __init__(self, color, length, width):
        super().__init__(color)
        self.length = length
        self.width = width
    def area(self):
        return self.length * self.width
r = Rectangle("Blue", 10, 5)
print("Color:", r.color)
print("Area:", r.area())
# Out:
# Color: Blue
# Area: 50

# %% [markdown]
# 27. Class Name: Employee
# Problem
# Create an abstract class named Employee.
# Explanation
# Store:
# • Employee name
# • Base salary
# Create abstract method:
# • calculate_bonus()
# Create subclass:
# • Developer
# Use super() to initialize the common employee information before calculating the bonus.

# %%
from abc import ABC, abstractmethod
class Employee(ABC):
    def __init__(self, name, base_salary):
        self.name = name
        self.base_salary = base_salary
    @abstractmethod
    def calculate_bonus(self):
        pass
class Developer(Employee):
    def __init__(self, name, base_salary):
        super().__init__(name, base_salary)
    def calculate_bonus(self):
        return self.base_salary * 0.10  
d = Developer("aksh", 100000)
print("Employee Name:", d.name)
print("Base Salary:", d.base_salary)
print("Bonus:", d.calculate_bonus())
# Out:
# Employee Name: aksh
# Base Salary: 100000
# Bonus: 10000.0

# %% [markdown]
# 29. Class Name: Calculator
# Problem
# Create an abstract class named Calculator.
# Explanation
# Store the calculator name.
# __init__(self, name)
# Create abstract method:
# • compute(a, b)
# Create subclass:
# • ScientificCalculator
# Use super() to initialize the calculator name.

# %%
from abc import ABC, abstractmethod
class Calculator(ABC):
    def __init__(self, name):
        self.name = name
    @abstractmethod
    def compute(self, a, b):
        pass
class Scientific_cal(Calculator):
    def __init__(self, name):
        super().__init__(name)
    def compute(self, a, b):
        return a + b   
c = Scientific_cal("calsy")
print("Calculator Name:", c.name)
print("Result:", c.compute(10, 20))
# Out:
# Calculator Name: calsy
# Result: 30

# %% [markdown]
# 30. Class Name: Report
# Problem
# Create an abstract class named Report.
# Explanation
# Store:
# • Report title
# Add a normal method:
# • show_header()
# Create abstract method:
# • generate()
# Create subclasses:
# • PDFReport
# • HTMLReport
# Use super() to:
# • initialize the title using super().__init__()
# • call the parent method using super().show_header()
# • then generate the report in the subclass.

# %%
from abc import ABC, abstractmethod
class Report(ABC):
    def __init__(self, title):
        self.title = title
    def show_header(self):
        print("Report Title:", self.title)
    @abstractmethod
    def generate(self):
        pass
class PDFReport(Report):
    def __init__(self, title):
        super().__init__(title)
    def generate(self):
        super().show_header()
        print("Generating pdf Report")
class HTMLReport(Report):
    def __init__(self, title):
        super().__init__(title)
    def generate(self):
        super().show_header()
        print("Generating html Report")
p = PDFReport("Annual Report")
p.generate()
print()
h = HTMLReport("Sales Report")
h.generate()
# Out:
# Report Title: Annual Report
# Generating pdf Report
#
# Report Title: Sales Report
# Generating html Report
