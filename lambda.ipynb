# %%
square = lambda x: x ** 2
print(square(2))
# Out:
# 4

# %%
cube = lambda x: x ** 3
print(cube(2))
# Out:
# 8

# %%
add=lambda x,y:x+y
print(add(10,20))
# Out:
# 30

# %%
find_max = lambda x, y: x if x > y else y
print(find_max(15, 8))
# Out:
# 15

# %%
check_even_odd = lambda x: "Even" if x % 2 == 0 else "Odd"
print(check_even_odd(9))
# Out:
# Odd

# %%
numbers = [1, 2, 3, 4]
square = list(map(lambda x: x ** 2, numbers))
print(square)
# Out:
# [1, 4, 9, 16]

# %%
numbers = [1, 2, 3, 4, 5, 6]
even = list(filter(lambda x: x % 2 == 0, numbers))
print(even)
# Out:
# [2, 4, 6]

# %%
numbers = [20, 45, 55, 70]
greater = list(filter(lambda x: x > 50, numbers))
print(greater)
# Out:
# [55, 70]

# %%
numbers = [9, 5, 1, 8, 2]
sorted_numbers = sorted(numbers, key=lambda x: x)
print(sorted_numbers)
# Out:
# [1, 2, 5, 8, 9]

# %%
numbers = [9, 5, 1, 8, 2]
sorted_numbers_desc = sorted(numbers, key=lambda x: -x)
print(sorted_numbers_desc)
# Out:
# [9, 8, 5, 2, 1]

# %%
from functools import reduce
numbers = [10, 20, 30, 40]
total_sum = reduce(lambda x, y: x + y, numbers)
print(total_sum)
# Out:
# 100

# %%
from functools import reduce

numbers = [2, 3, 4, 5]
total_product = reduce(lambda x, y: x * y, numbers)
print(total_product)
# Out:
# 120

# %%
students = [
    ("Ram", 22),
    ("Amit", 19),
    ("Neha", 25),
    ("Raj", 20)
]
sorted_students = sorted(students, key=lambda student: student[1])
print(sorted_students)
# Out:
# [('Amit', 19), ('Raj', 20), ('Ram', 22), ('Neha', 25)]

# %%
marks = {
    "A": 80,
    "B": 95,
    "C": 70,
    "D": 88
}
sorted_marks = dict(sorted(marks.items(), key=lambda item: item[1]))

print(sorted_marks)
# Out:
# {'C': 70, 'A': 80, 'D': 88, 'B': 95}

# %%
strings = ["apple", "banana", "kiwi", "watermelon"]
longest_string = max(strings, key=lambda s: len(s))
print(longest_string)
# Out:
# watermelon

# %%
students = [
    ("Ram", 85),
    ("Amit", 91),
    ("Neha", 78)
]
topper = max(students, key=lambda student: student[1])
print(topper)
# Out:
# ('Amit', 91)

# %%
employees = [
    ("A", 35000),
    ("B", 42000),
    ("C", 28000)
]
lowest_paid_employee = min(employees, key=lambda emp: emp[1])

print(lowest_paid_employee)
# Out:
# ('C', 28000)

# %%
names = ["ram", "amit", "neha"]
uppercase_names = list(map(lambda name: name.upper(), names))

print(uppercase_names)
# Out:
# ['RAM', 'AMIT', 'NEHA']

# %%
words = ["apple", "banana", "kiwi", "orange", "grapes"]

filtered_words = list(filter(lambda w: len(w) > 5, words))
print(filtered_words)
# Out:
# ['banana', 'orange', 'grapes']

# %%
tuples_list = [(1, 5), (3, 2), (2, 8), (4, 1)]
sorted_tuples = sorted(tuples_list, key=lambda x: x[1])
print(sorted_tuples)
# Out:
# [(4, 1), (3, 2), (1, 5), (2, 8)]

# %%
employees = [
    {"name": "Ram", "salary": 50000},
    {"name": "Amit", "salary": 65000},
    {"name": "Neha", "salary": 45000}
]

sorted_employees = sorted(employees, key=lambda emp: emp["salary"])
print(sorted_employees)
# Out:
# [{'name': 'Neha', 'salary': 45000}, {'name': 'Ram', 'salary': 50000}, {'name': 'Amit', 'salary': 65000}]

# %%
students = [
    ("Ram", 90),
    ("Amit", 90),
    ("Neha", 85),
    ("Raj", 95)
]

sorted_students = sorted(students, key=lambda x: (-x[1], x[0]))
print(sorted_students)
# Out:
# [('Raj', 95), ('Amit', 90), ('Ram', 90), ('Neha', 85)]

# %%
multiply = lambda x: lambda y: x * y
print(multiply(5)(10))
# Out:
# 50

# %%
power = lambda n: lambda x: x ** n
square = power(2)
print(square(6))
# Out:
# 36

# %%
numbers = [-5, 10, -3, 8, 0, -1, 20]
positive_numbers = list(filter(lambda x: x >= 0, numbers))
print(positive_numbers)
# Out:
# [10, 8, 0, 20]

# %%
numbers = [1, 2, 3, 4, 5, 6]
processed_numbers = list(map(lambda x: x**2 if x % 2 != 0 else x, numbers))

print(processed_numbers)
# Out:
# [1, 2, 9, 4, 25, 6]

# %%
strings = ["apple", "banana", "kiwi", "grape"]
sorted_strings = sorted(strings, key=lambda x: x[-1])
print(sorted_strings)
# Out:
# ['banana', 'apple', 'grape', 'kiwi']

# %%
employees = [
    ("A", 45000),
    ("B", 60000),
    ("C", 52000),
    ("D", 75000)
]
second_highest = sorted(employees, key=lambda emp: emp[1], reverse=True)
print(second_highest[1])
# Out:
# ('B', 60000)
