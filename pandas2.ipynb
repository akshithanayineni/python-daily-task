# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\LENOVO\\Downloads\\Bank_customer_churn - Bank_customer_churn.csv")
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
Display the last 15 customers.

# %%
df.tail(15)
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography  Gender  Age  \
# 9985       9986    15586914       Nepean          659    France    Male   36
# 9986       9987    15581736     Bartlett          673   Germany    Male   47
# 9987       9988    15588839      Mancini          606     Spain    Male   30
# 9988       9989    15589329      Pirozzi          775    France    Male   30
# 9989       9990    15605622     McMillan          841     Spain    Male   28
# 9990       9991    15798964   Nkemakonam          714   Germany    Male   33
# 9991       9992    15769959  Ajuluchukwu          597    France  Female   53
# 9992       9993    15657105  Chukwualuka          726     Spain    Male   36
# 9993       9994    15569266       Rahman          644    France    Male   28
# 9994       9995    15719294         Wood          800    France  Female   29
# 9995       9996    15606229     Obijiaku          771    France    Male   39
# ...

# %%
Show 7 random customer records.

# %%
df.sample(7)
# Out:
#       RowNumber  CustomerId          Surname  CreditScore Geography  Gender  \
# 4362       4363    15618695            Ts'ui          571     Spain  Female
# 9796       9797    15794236           Thorpe          642   Germany    Male
# 9932       9933    15813451  Fleetwood-Smith          677     Spain    Male
# 7034       7035    15767264           Lawson          465   Germany    Male
# 4086       4087    15764294           Ifeatu          759   Germany    Male
# 4760       4761    15713949            Woods          850    France    Male
# 1953       1954    15675190             Chia          623    France    Male
#
#       Age  Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 4362   22       3  108117.10              1          0               1
# 9796   22      10  111812.52              2          1               1
# 9932   18       8  134796.87              2          1               1
# 7034   53       1  117438.17              1          0               0
# ...

# %%
Print complete dataset information and identify:
• Total columns
• Data type of each column
• Missing values

# %%
df.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
df.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
Display only numerical columns.

# %%
df.select_dtypes(include='number')
# Out:
#       RowNumber  CustomerId  CreditScore  Age  Tenure    Balance  \
# 0             1    15634602          619   42       2       0.00
# 1             2    15647311          608   41       1   83807.86
# 2             3    15619304          502   42       8  159660.80
# 3             4    15701354          699   39       1       0.00
# 4             5    15737888          850   43       2  125510.82
# ...         ...         ...          ...  ...     ...        ...
# 9995       9996    15606229          771   39       5       0.00
# 9996       9997    15569892          516   35      10   57369.61
# 9997       9998    15584532          709   36       7       0.00
# 9998       9999    15682355          772   42       3   75075.31
# 9999      10000    15628319          792   28       4  130142.79
#
#       NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0                 1          1               1        101348.88       1
# ...

# %%
Generate the statistical summary of numerical columns.

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
Find duplicate rows and print how many exist.

# %%
duplicates = df.duplicated().sum()
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
Remove duplicate rows and store the cleaned dataset.

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
Count how many customers have exited and how many have not exited.

# %%
exit_count = df["Exited"].value_counts()
print(exit_count)
# Out:
# Exited
# 0    7963
# 1    2037
# Name: count, dtype: int64

# %%
Medium Level (11–20)
Q11
Rename the following columns:
CustomerId → Customer_ID
CreditScore → Credit_Score
EstimatedSalary → Salary
Exited → Churn

# %%
df.rename(columns={
    "CustomerId": "Customer_ID",
    "CreditScore": "Credit_Score",
    "EstimatedSalary": "Salary",
    "Exited": "Churn"
}, inplace=True)
df.columns
# Out:
# Index(['RowNumber', 'Customer_ID', 'Surname', 'Credit_Score', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'Salary', 'Churn'],
#       dtype='object')

# %%
Add the prefix
Bank_
to every column name.

# %%
df = df.add_prefix("Bank_")

# %%
df.columns
# Out:
# Index(['Bank_RowNumber', 'Bank_Customer_ID', 'Bank_Surname',
#        'Bank_Credit_Score', 'Bank_Geography', 'Bank_Gender', 'Bank_Age',
#        'Bank_Tenure', 'Bank_Balance', 'Bank_NumOfProducts', 'Bank_HasCrCard',
#        'Bank_IsActiveMember', 'Bank_Salary', 'Bank_Churn'],
#       dtype='object')

# %%
Convert the Age column into float datatype.

# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\LENOVO\\Downloads\\Bank_customer_churn - Bank_customer_churn.csv")
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
df["Age"] = df["Age"].astype(float)
print(df['Age'].dtypes)
# Out:
# float64

# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\LENOVO\\Downloads\\Bank_customer_churn - Bank_customer_churn.csv")
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
Q14
Convert the Exited column into string datatype.

# %%
df["Exited"] = df["Exited"].astype(str)
print(df["Exited"].dtype)
# Out:
# object

# %%
Q15
Suppose the Balance column has missing values.
Replace them using the mean of the Balance column.

# %%
df["Balance"]=df["Balance"].fillna(df["Balance"].mean())
print(df['Balance'])
# Out:
# 0            0.00
# 1        83807.86
# 2       159660.80
# 3            0.00
# 4       125510.82
#           ...
# 9995         0.00
# 9996     57369.61
# 9997         0.00
# 9998     75075.31
# 9999    130142.79
# Name: Balance, Length: 10000, dtype: float64

# %%
Q16
Suppose the Age column has missing values.
Replace them using the median age.

# %%
df["Balance"]=df["Balance"].fillna(df["Balance"].median())
print(df['Balance'])
# Out:
# 0            0.00
# 1        83807.86
# 2       159660.80
# 3            0.00
# 4       125510.82
#           ...
# 9995         0.00
# 9996     57369.61
# 9997         0.00
# 9998     75075.31
# 9999    130142.79
# Name: Balance, Length: 10000, dtype: float64

# %%
Q18
Create a new DataFrame by dropping these columns:
RowNumber
CustomerId
Surname
Display the first 10 rows.

# %%
df.drop(columns=["RowNumber", "CustomerId", "Surname"]).head(10)
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
# 5          645     Spain    Male   44       8  113755.78              2
# 6          822    France    Male   50       7       0.00              2
# 7          376   Germany  Female   29       4  115046.74              4
# 8          501    France    Male   44       4  142051.07              2
# 9          684    France    Male   27       2  134603.88              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary Exited
# 0          1               1        101348.88      1
# 1          0               1        112542.58      0
# ...

# %%
Q19
Drop the Geography column and display dataset information again.

# %%
df.drop(columns=["Geography"]).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Gender           10000 non-null  object
#  5   Age              10000 non-null  int64
#  6   Tenure           10000 non-null  int64
#  7   Balance          10000 non-null  float64
#  8   NumOfProducts    10000 non-null  int64
#  9   HasCrCard        10000 non-null  int64
#  10  IsActiveMember   10000 non-null  int64
#  11  EstimatedSalary  10000 non-null  float64
#  12  Exited           10000 non-null  object
# dtypes: float64(2), int64(8), object(3)
# memory usage: 1015.8+ KB

# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\LENOVO\\Downloads\\Bank_customer_churn - Bank_customer_churn.csv")
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
Q20
Rename NumOfProducts to Products and HasCrCard to CreditCard.

# %%
df.rename(columns={"NumOfProducts": "Products", "HasCrCard": "CreditCard"})
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  Products  CreditCard  IsActiveMember  \
# ...

# %%
Q21 (Real Company Task)
Your manager wants cleaner column names.
Rename every column as follows:
RowNumber → Row_No
CustomerId → Customer_ID
Surname → Last_Name
CreditScore → Credit_Score
Geography → Country
Gender → Sex
EstimatedSalary → Salary
Exited → Target

# %%
df.rename(columns={"RowNumber":"Row_No","CustomerId":"Customer_ID","Surname":"Last_Name","CreditScore":"Credit_Score","Geography":"Country","Gender":"Sex","EstimatedSalary":"Salary","Exited":"Target"}, inplace=True)
df.head(5)
# Out:
#    Row_No  Customer_ID Last_Name  Credit_Score Country     Sex  Age  Tenure  \
# 0       1     15634602  Hargrave           619  France  Female   42       2
# 1       2     15647311      Hill           608   Spain  Female   41       1
# 2       3     15619304      Onio           502  France  Female   42       8
# 3       4     15701354      Boni           699  France  Female   39       1
# 4       5     15737888  Mitchell           850   Spain  Female   43       2
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember     Salary  Target
# 0       0.00              1          1               1  101348.88       1
# 1   83807.86              1          0               1  112542.58       0
# 2  159660.80              3          1               0  113931.57       1
# 3       0.00              2          0               0   93826.63       0
# 4  125510.82              1          1               1   79084.10       0

# %%
Q22
Create a new DataFrame that contains only numeric columns.
Then generate its statistical summary.

# %%
df_numeric = df.select_dtypes(include="number")
df_numeric.describe()
# Out:
#             Row_No   Customer_ID  Credit_Score           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\LENOVO\\Downloads\\Bank_customer_churn - Bank_customer_churn.csv")
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
Q23
Your company received duplicate customer records.
Tasks:
• Count duplicates.
• Remove duplicates.
• Display dataset information after cleaning.

# %%
print(df.duplicated().sum())
df.drop_duplicates(inplace=True)
df.info()
# Out:
# 0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
Q24
Management wants every column name to begin with
Customer_
Apply this transformation using the appropriate method.

# %%
df = df.add_prefix("Customer_")
df
# Out:
#       Customer_Customer_Customer_Customer_RowNumber  \
# 0                                                 1
# 1                                                 2
# 2                                                 3
# 3                                                 4
# 4                                                 5
# ...                                             ...
# 9995                                           9996
# 9996                                           9997
# 9997                                           9998
# 9998                                           9999
# 9999                                          10000
#
#       Customer_Customer_Customer_Customer_CustomerId  \
# 0                                           15634602
# 1                                           15647311
# 2                                           15619304
# 3                                           15701354
# 4                                           15737888
# ...

# %%
import pandas as pd

# 1. Load dataset
df = pd.read_csv("Churn_Modelling.csv")

# 2. Display dataset information
df.info()

# 3. Check missing values
print(df.isnull().sum())

# 4. Remove duplicate rows
df.drop_duplicates(inplace=True)

# 5. Rename columns
df.rename(columns={
    "CustomerId": "Customer_ID",
    "CreditScore": "Credit_Score",
    "EstimatedSalary": "Salary",
    "Exited": "Target"
}, inplace=True)

# 6. Convert datatypes
df["Age"] = df["Age"].astype(float)
df["Balance"] = df["Balance"].astype(float)
df["Target"] = df["Target"].astype(str)

# 7. Replace missing values
df["Age"] = df["Age"].fillna(df["Age"].median())
df["Balance"] = df["Balance"].fillna(df["Balance"].mean())

# 8. Remove columns
df.drop(columns=["RowNumber", "Surname"], inplace=True)

# 9. Display outputs
print(df.head(10))

print(df.describe())

print(df["Target"].value_counts())

df.info()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
Q25
After renaming the columns, convert
Age
Balance
EstimatedSalary
to float datatype.
Print dataset information.

# %%
df[["Age", "Balance", "EstimatedSalary"]] = df[["Age", "Balance", "EstimatedSalary"]].astype(float)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  float64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(3), int64(8), object(3)
# memory usage: 1.1+ MB

# %%
Q26
Assume CreditScore contains missing values.
Replace them with the median CreditScore.

# %%
df["CreditScore"] = df["CreditScore"].fillna(df["CreditScore"].median())
print(df['CreditScore'].isnull().sum())
# Out:
# 0

# %%
Q27
Assume EstimatedSalary contains missing values.
Replace them with the mean salary.
Then print the first eight rows.

# %%
df["EstimatedSalary"] = df["EstimatedSalary"].fillna(df["EstimatedSalary"].mean())
print(df['EstimatedSalary'].isnull().sum())
df.head(8)
# Out:
# 0
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender   Age  \
# 0          1    15634602  Hargrave          619    France  Female  42.0
# 1          2    15647311      Hill          608     Spain  Female  41.0
# 2          3    15619304      Onio          502    France  Female  42.0
# 3          4    15701354      Boni          699    France  Female  39.0
# 4          5    15737888  Mitchell          850     Spain  Female  43.0
# 5          6    15574012       Chu          645     Spain    Male  44.0
# 6          7    15592531  Bartlett          822    France    Male  50.0
# 7          8    15656148    Obinna          376   Germany  Female  29.0
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# ...

# %%
Q28 (Data Cleaning Challenge)
Perform all the following:
• Remove duplicate rows.
• Rename Exited to Target.
• Convert Target to string.
• Display dataset information.

# %%
df.drop_duplicates(inplace=True)
df.rename(columns={"Exited":"Target"}, inplace=True)
df["Target"] = df["Target"].astype(str)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  float64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Target           10000 non-null  object
# dtypes: float64(3), int64(7), object(4)
# memory usage: 1.1+ MB

# %%
Q29 (Transformation Challenge)
Create a copy of the dataset.
Perform these transformations:
• Rename Gender to CustomerGender
• Rename Geography to Country
• Add prefix Bank_
• Remove RowNumber
• Display first 10 rows

# %%
df_copy = df.copy()
df_copy.rename(columns={"Gender":"CustomerGender","Geography":"Country"}, inplace=True)
df_copy = df_copy.add_prefix("Bank_")
df_copy.drop(columns=["Bank_RowNumber"], inplace=True)
df_copy.head(10)
# Out:
#    Bank_CustomerId Bank_Surname  Bank_CreditScore Bank_Country  \
# 0         15634602     Hargrave               619       France
# 1         15647311         Hill               608        Spain
# 2         15619304         Onio               502       France
# 3         15701354         Boni               699       France
# 4         15737888     Mitchell               850        Spain
# 5         15574012          Chu               645        Spain
# 6         15592531     Bartlett               822       France
# 7         15656148       Obinna               376      Germany
# 8         15792365           He               501       France
# 9         15592389           H?               684       France
#
#   Bank_CustomerGender  Bank_Age  Bank_Tenure  Bank_Balance  \
# 0              Female      42.0            2          0.00
# 1              Female      41.0            1      83807.86
# 2              Female      42.0            8     159660.80
# ...

# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\LENOVO\\Downloads\\Bank_customer_churn - Bank_customer_churn.csv")
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
df.info()
print(df.isnull().sum())
df.drop_duplicates(inplace=True)
df.rename(columns={
    "CustomerId": "Customer_ID",
    "CreditScore": "Credit_Score",
    "EstimatedSalary": "Salary",
    "Exited": "Target"
}, inplace=True)
df["Age"] = df["Age"].astype(float)
df["Balance"] = df["Balance"].astype(float)
df["Target"] = df["Target"].astype(str)
df["Age"] = df["Age"].fillna(df["Age"].median())
df["Balance"] = df["Balance"].fillna(df["Balance"].mean())
df.drop(columns=["RowNumber", "Surname"], inplace=True)
print(df.head(10))
print(df.describe())
print(df["Target"].value_counts())
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB
# RowNumber          0
# CustomerId         0
# Surname            0
# ...

# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\LENOVO\\Downloads\\Bank_customer_churn - Bank_customer_churn.csv")
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
Bonus Challenge (Create New Columns)
These require creating new columns using basic Pandas assignment along with the methods
you've learned.
B1
Create a new column:
TotalMoney = Balance + EstimatedSalary

B2
Create a new column:
DoubleScore = CreditScore × 2

B3
Create a new column:
AgeAfter10Years = Age + 10

B4
Create a new column:
HasBalance = Balance
Replace missing values in this new column using the mean.

B5

Create a new column:
SalaryInLakhs = EstimatedSalary / 100000

# %%
df["TotalMoney"] = df["Balance"] + df["EstimatedSalary"]

df["DoubleScore"] = df["CreditScore"] * 2

df["AgeAfter10Years"] = df["Age"] + 10

df["HasBalance"] = df["Balance"]
df["HasBalance"] = df["HasBalance"].fillna(df["HasBalance"].mean())

df["SalaryInLakhs"] = df["EstimatedSalary"] / 100000

df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited  TotalMoney  DoubleScore  AgeAfter10Years  \
# 0        101348.88       1   101348.88         1238               52
# ...

# %%
df[["TotalMoney", "DoubleScore", "AgeAfter10Years", "HasBalance", "SalaryInLakhs"]].head()
# Out:
#    TotalMoney  DoubleScore  AgeAfter10Years  HasBalance  SalaryInLakhs
# 0   101348.88         1238               52        0.00       1.013489
# 1   196350.44         1216               51    83807.86       1.125426
# 2   273592.37         1004               52   159660.80       1.139316
# 3    93826.63         1398               49        0.00       0.938266
# 4   204594.92         1700               53   125510.82       0.790841
