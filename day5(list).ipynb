# %%
List=["aksh","varsh","hema","jyothi","neha"]
print(List)
# Out:
# ['aksh', 'varsh', 'hema', 'jyothi', 'neha']

# %%
List=[10,20,30,40,50]
print(type(List))
print(len(List))
# Out:
# <class 'list'>
# 5

# %% [markdown]
# #append

# %%
#append
a=[]
a.append(3)
a.append(2)
a.append(5)
print(a)
# Out:
# [3, 2, 5]

# %% [markdown]
# #extend

# %%
#extend
List=[1,2,3]
List.extend([4,5,6])
print(List)
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# #insert

# %%
#insert
List=[10,20,30,40]
List.insert(2,100)
print(List)
# Out:
# [10, 20, 100, 30, 40]

# %% [markdown]
# #remove

# %%
#remove
List=[10,20,50,30,50]
List.remove(50)
print(List)
# Out:
# [10, 20, 30, 50]

# %% [markdown]
# #pop

# %%
List=[5,10,15,20]
List.pop()
print(List)
# Out:
# [5, 10, 15]

# %% [markdown]
# #clear

# %%
List=[1,2,3,4,5]
List.clear()
print(List)
# Out:
# []

# %% [markdown]
# #Medium level ques

# %%
List=["10","15","25","30","40"]
List.index("25")
# Out:
# 2

# %% [markdown]
# #count

# %%
List=[7,2,7,5,7,8]
print(List.count(7))
# Out:
# 3

# %% [markdown]
# #sort

# %%
List=["45","12","78","23","56"]
List.sort()
print(List)
# Out:
# ['12', '23', '45', '56', '78']

# %%
List=["45","12","78","23","56"]
List.sort(reverse=True)
print(List)
# Out:
# ['78', '56', '45', '23', '12']

# %% [markdown]
# #Reverse

# %%
fruits=["apple","banana","mango","orange"]
fruits.reverse()
print(fruits)
# Out:
# ['orange', 'mango', 'banana', 'apple']

# %% [markdown]
# #split

# %%
a="i love python"
words=a.split()
print(words)
# Out:
# ['i', 'love', 'python']

# %% [markdown]
# #reverse

# %%
a=[1,2,3,4,5]
a.append(6)
a.append(7)
a.append(8)
a.sort(reverse=True)
print(a)
# Out:
# [8, 7, 6, 5, 4, 3, 2, 1]

# %%
a=[1,2,3,4,5]
a.insert(0,"PYTHON")
print(a)
a.pop()
print(a)
print(len(a))
# Out:
# ['PYTHON', 1, 2, 3, 4, 5]
# ['PYTHON', 1, 2, 3, 4]
# 5

# %%
city1=input()
city2=input()
city3=input()
city4=input()
city5=input()
cities=[city1,city2,city3,city4,city5]
cities.reverse()
print(cities)
# Out:
#  hyd
#  warangal
#  sdpt
#  khammam
#  warangal
# ['warangal', 'khammam', 'sdpt', 'warangal', 'hyd']

# %% [markdown]
# #remove

# %%
data=[10,20,30,20,40,20]
data.remove(20)
print(data)
data.remove(20)
print(data)
data.remove(20)
print(data)
# Out:
# [10, 30, 20, 40, 20]
# [10, 30, 40, 20]
# [10, 30, 40]

# %% [markdown]
# #sort

# %%
sub1=int(input())
sub2=int(input())
sub3=int(input())
sub4=int(input())
sub5=int(input())
marks=[sub1,sub2,sub3,sub4,sub5]
marks.sort()
print(marks)
print("lowest marks:",marks[0])
print("highest marks:",marks[-1])
# Out:
#  23
#  67
#  54
#  98
#  34
# [23, 34, 54, 67, 98]
# lowest marks: 23
# highest marks: 98
